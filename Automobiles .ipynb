# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Automobile.csv")

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.tail(10)
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 191         -1                 74  volvo       gas        std            four
# 192         -2                103  volvo       gas        std            four
# 193         -1                 74  volvo       gas        std            four
# 194         -2                103  volvo       gas      turbo            four
# 195         -1                 74  volvo       gas      turbo            four
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# ...

# %%
print(df.shape)
print(df.size)
# Out:
# (201, 26)
# 5226

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %%
df.count()
# Out:
# symboling              201
# normalized_losses      201
# make                   201
# fuel_type              201
# aspiration             201
# number_of_doors        201
# body_style             201
# drive_wheels           201
# engine_location        201
# wheel_base             201
# length                 201
# width                  201
# height                 201
# curb_weight            201
# engine_type            201
# number_of_cylinders    201
# engine_size            201
# fuel_system            201
# bore                   201
# stroke                 201
# compression_ratio      201
# horsepower             201
# peak_rpm               201
# city_mpg               201
# highway_mpg            201
# price                  201
# dtype: int64

# %%
df.isnull().sum()
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %%
df.count()
# Out:
# symboling              201
# normalized_losses      201
# make                   201
# fuel_type              201
# aspiration             201
# number_of_doors        201
# body_style             201
# drive_wheels           201
# engine_location        201
# wheel_base             201
# length                 201
# width                  201
# height                 201
# curb_weight            201
# engine_type            201
# number_of_cylinders    201
# engine_size            201
# fuel_system            201
# bore                   201
# stroke                 201
# compression_ratio      201
# horsepower             201
# peak_rpm               201
# city_mpg               201
# highway_mpg            201
# price                  201
# dtype: int64

# %%
df.isnull()
# Out:
#      symboling  normalized_losses   make  fuel_type  aspiration  \
# 0        False              False  False      False       False
# 1        False              False  False      False       False
# 2        False              False  False      False       False
# 3        False              False  False      False       False
# 4        False              False  False      False       False
# ..         ...                ...    ...        ...         ...
# 196      False              False  False      False       False
# 197      False              False  False      False       False
# 198      False              False  False      False       False
# 199      False              False  False      False       False
# 200      False              False  False      False       False
#
#      number_of_doors  body_style  drive_wheels  engine_location  wheel_base  \
# 0              False       False         False            False       False
# ...

# %%
df.isnull().any()
# Out:
# symboling              False
# normalized_losses      False
# make                   False
# fuel_type              False
# aspiration             False
# number_of_doors        False
# body_style             False
# drive_wheels           False
# engine_location        False
# wheel_base             False
# length                 False
# width                  False
# height                 False
# curb_weight            False
# engine_type            False
# number_of_cylinders    False
# engine_size            False
# fuel_system            False
# bore                   False
# stroke                 False
# compression_ratio      False
# horsepower             False
# peak_rpm               False
# city_mpg               False
# highway_mpg            False
# price                  False
# dtype: bool

# %%
null_cols=df.columns[df.isnull().any()]
null_cols=list(null_cols)

# %%
df['length'].count()
# Out:
# 201

# %%
df['height'].std()
# Out:
# 2.44782216129631

# %%
df['length'].mean()
# Out:
# 174.20099502487562

# %%
df.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace("_", " ")
df.columns
# Out:
# Index(['symboling', 'normalized losses', 'make', 'fuel type', 'aspiration',
#        'number of doors', 'body style', 'drive wheels', 'engine location',
#        'wheel base', 'length', 'width', 'height', 'curb weight', 'engine type',
#        'number of cylinders', 'engine size', 'fuel system', 'bore', 'stroke',
#        'compression ratio', 'horsepower', 'peak rpm', 'city mpg',
#        'highway mpg', 'price'],
#       dtype='object')

# %%
df.head()
# Out:
#    symboling  normalized losses         make fuel type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number of doors   body style drive wheels engine location  wheel base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine size  fuel system  bore  stroke compression ratio horsepower  \
# ...

# %%
df[df['price']>15000]
# Out:
#      symboling  normalized losses         make fuel type aspiration  \
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# 6            1                158         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number of doors   body style drive wheels engine location  wheel base  \
# 1               two  convertible          rwd           front        88.6
# ...

# %%
df.query('price > 15000')
# Out:
#      symboling  normalized losses         make fuel type aspiration  \
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# 6            1                158         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number of doors   body style drive wheels engine location  wheel base  \
# 1               two  convertible          rwd           front        88.6
# ...

# %%
df.price.max()
# Out:
# 45400

# %%
df.describe()
# Out:
#         symboling  normalized losses  wheel base      length       width  \
# count  201.000000         201.000000  201.000000  201.000000  201.000000
# mean     0.840796         125.189055   98.797015  174.200995   65.889055
# std      1.254802          33.572966    6.066366   12.322175    2.101471
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.800000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.500000   66.600000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb weight  engine size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.329701    3.261741
# std      2.447822   517.296727    41.546834    0.268166    0.317875
# ...

# %%
df.columns = df.columns.str.replace(" ", "_")
df.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
len(df)
# Out:
# 201

# %%
df_dropped = df.drop('aspiration', axis = 1)
df_dropped
# Out:
#      symboling  normalized_losses         make fuel_type number_of_doors  \
# 0            3                168  alfa-romero       gas             two
# 1            3                168  alfa-romero       gas             two
# 2            1                168  alfa-romero       gas             two
# 3            2                164         audi       gas            four
# 4            2                164         audi       gas            four
# ..         ...                ...          ...       ...             ...
# 196         -1                 95        volvo       gas            four
# 197         -1                 95        volvo       gas            four
# 198         -1                 95        volvo       gas            four
# 199         -1                 95        volvo    diesel            four
# 200         -1                 95        volvo       gas            four
#
#       body_style drive_wheels engine_location  wheel_base  length  ...  \
# ...

# %%
df
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
print(df['make'].unique())
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']

# %%
print(df['aspiration'].unique())
# Out:
# ['std' 'turbo']

# %%
print(df['make'].unique())
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']

# %%
df.groupby('body_style')['price'].sum().sort_values(ascending = False).head(20)
# Out:
# body_style
# sedan          1359217
# hatchback       677106
# wagon           309299
# hardtop         177668
# convertible     131343
# Name: price, dtype: int64

# %%
df['price'].std()
# Out:
# 7947.066341939271

# %%
pols = df.groupby('body_style')['price'].sum().head(10)
pols
po5 = pols.reset_index()
po5.columns = ['body_style', 'price']

import seaborn as sns
sns.barplot(data = po5, x='body_style', y='price')
# Out:
# <Axes: xlabel='body_style', ylabel='price'>

# %%
sns.distplot(x = df['price'], bins = 10)
# Out:
# C:\Users\ajeet\AppData\Local\Temp\ipykernel_25500\3927708983.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = df['price'], bins = 10)
# <Axes: ylabel='Density'>

# %%
df.hist(by = 'bore', column = 'price', figsize=(10,15))
# Out:
# array([[<Axes: title={'center': '2.54'}>,
#         <Axes: title={'center': '2.68'}>,
#         <Axes: title={'center': '2.91'}>,
#         <Axes: title={'center': '2.92'}>,
#         <Axes: title={'center': '2.97'}>,
#         <Axes: title={'center': '2.99'}>],
#        [<Axes: title={'center': '3.01'}>,
#         <Axes: title={'center': '3.03'}>,
#         <Axes: title={'center': '3.05'}>,
#         <Axes: title={'center': '3.08'}>,
#         <Axes: title={'center': '3.13'}>,
#         <Axes: title={'center': '3.15'}>],
#        [<Axes: title={'center': '3.17'}>,
#         <Axes: title={'center': '3.19'}>,
#         <Axes: title={'center': '3.24'}>,
#         <Axes: title={'center': '3.27'}>,
#         <Axes: title={'center': '3.28'}>,
#         <Axes: title={'center': '3.31'}>],
#        [<Axes: title={'center': '3.33'}>,
#         <Axes: title={'center': '3.34'}>,
#         <Axes: title={'center': '3.35'}>,
#         <Axes: title={'center': '3.39'}>,
# ...

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
sns.lineplot(x="stroke", y="price", data=df)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
import matplotlib.pyplot as plt

# %%
graph = sns.PairGrid(df, hue ='price')
# type of graph for diagonal
graph = graph.map_diag(plt.hist)
# type of graph for non-diagonal
graph = graph.map_offdiag(plt.scatter)
# to add legends
graph = graph.add_legend()
# to show
plt.show()

# %%
pip install seaborn[stats]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install seaborn
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.05.30 |       haa95532_0         120 KB
#     certifi-2023.5.7           |  py310haa95532_0         153 KB
#     openssl-1.1.1u             |       h2bbff1b_0         5.5 MB
#     ------------------------------------------------------------
#                                            Total:         5.8 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.01.10-haa95532_0 --> 2023.05.30-haa95532_0
#   certifi                         2022.12.7-py310haa95532_0 --> 2023.5.7-py310haa95532_0
#   openssl                                 1.1.1t-h2bbff1b_0 --> 1.1.1u-h2bbff1b_0
#
#
#
# ...
#
# ...

# %%
conda install seaborn -c conda-forge
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - seaborn
#
#
# The following NEW packages will be INSTALLED:
#
#   seaborn-base       conda-forge/noarch::seaborn-base-0.12.2-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2023.5.7-h56e8100_0
#   certifi            pkgs/main/win-64::certifi-2022.12.7-p~ --> conda-forge/noarch::certifi-2023.5.7-pyhd8ed1ab_0
#   openssl                                 1.1.1t-h2bbff1b_0 --> 1.1.1u-h2bbff1b_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   seaborn            pkgs/main/win-64::seaborn-0.12.2-py31~ --> conda-forge/noarch::seaborn-0.12.2-hd8ed1ab_0
#
#
#
# ...
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... failed
#
# ...

# %%
sns.relplot(data=df, x="stroke", y="price")

# %%
sns.relplot(data=df, x="highway_mpg", y="price", hue="city_mpg", style="engine_size")

# %%
sns.relplot(data=df, x="price", y="wheel_base", kind="line")

# %%
from sklearn.linear_model import LinearRegression
# Out:
#   Cell In[50], line 2
#     conda create -n sklearn-env -c conda-forge scikit-learn
#           ^
# SyntaxError: invalid syntax

# %%
df.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %%
df.highway_mpg.max()
# Out:
# 54

# %%
X = df['highway_mpg'].tolist()
X2 = df['price'].tolist()
k = np.arange(90, 300, 10)
k
# Out:
# array([ 90, 100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200, 210,
#        220, 230, 240, 250, 260, 270, 280, 290])

# %%
X = np.array(X).reshape(-1, 1) 
X2 = np.array(X2)
model = LinearRegression()
model.fit(X, X2)
new_X = [60,70,80,90,  90, 100, 110, 120, 130, 140, 150, 160, 170, 180, 190, 200, 210,
       220, 230, 240, 250, 260, 270, 280, 290]
new_X = np.array(new_X).reshape(-1, 1)  # Reshape new_X to a column vector
predictions = model.predict(new_X)







# Plotting the predictions as a line chart
plt.plot(new_X, predictions, marker='o', linestyle='-', label='Predictions')
plt.xlabel('highway_mpg')
plt.ylabel('price')
plt.title('Regression Predictions')
plt.legend()
plt.show()

# %%
df.price.std()
# Out:
# 7947.066341939271

# %%
df.price.mean()
# Out:
# 13207.129353233831

# %%
z = (13500-13207)/7947
z
# Out:
# 0.03686925883981377

# %%
import scipy.stats as stats

# %%
stats.norm.cdf(z)
# Out:
# 0.5147053745166723

# %%
x = np.array(x).reshape(-1, 1) 
x
# Out:
# array([[97.40309346],
#        [10.60297159],
#        [52.23589992],
#        [11.2954758 ],
#        [65.74905131],
#        [17.20744943],
#        [28.43618901],
#        [16.18021296],
#        [16.02539886],
#        [84.39937726],
#        [43.430061  ],
#        [21.09547258],
#        [67.9692937 ],
#        [ 1.69448373],
#        [ 4.88858368],
#        [47.23620968],
#        [99.04118465],
#        [88.62569714],
#        [45.12810292],
#        [46.45678653],
#        [53.83487621],
#        [36.42568028],
#        [89.75974392],
#        [16.7103907 ],
#        [ 2.86508168],
#        [39.70565103],
#        [17.5500139 ],
#        [43.01551423],
#        [ 2.04685357],
#        [53.94414413],
#        [12.37257918],
#        [20.87094685],
#        [77.79973469],
#        [61.38244347],
#        [92.76503909],
#        [63.13234001],
#        [27.7615849 ],
#        [61.44118983],
#        [44.64565711],
#        [19.03419429],
#        [83.80145182],
# ...
