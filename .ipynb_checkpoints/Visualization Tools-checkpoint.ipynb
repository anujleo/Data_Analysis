# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True) #adds nice background
# %matplotlib inline
# tells python to actually display the graph

# %%
auto = pd.read_csv('Automobile.csv')

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
sns.distplot(auto['highway_mpg'], kde = True, rug = False)
# Out:
# C:\Users\ajeet\AppData\Local\Temp\ipykernel_12972\840946167.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(auto['highway_mpg'], kde = True, rug = False)
# <Axes: xlabel='highway_mpg', ylabel='Density'>

# %%
sns.distplot(auto['highway_mpg'], kde = False, rug = True)
# Out:
# C:\Users\ajeet\AppData\Local\Temp\ipykernel_12972\3890895380.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(auto['highway_mpg'], kde = False, rug = True)
# <Axes: xlabel='highway_mpg'>

# %%
sns.jointplot(auto['engine_size']);

# different from what we have in video tutorial, check again visualisation video nd

# %%
sns.jointplot(auto['engine_size'], kind = "hex");

# same issue its also not working with 2 arguments.

# %%
sns.jointplot(auto['engine_size']b, kind = "kde", rug = True)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'rug'
#   cset = contour_func(

# %%
sns.pairplot(auto[['normalized_losses', 'engine_size', 'horsepower']]);

# %%
#PUTTING CATEGORICAL DATA ON PLOT

# %%
# sns.stripplot(auto['fuel_type'], auto['horsepower'], jitter=False);

sns.stripplot(x=auto['fuel_type'], y=auto['horsepower'], jitter=True)
# Out:
# <Axes: xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.swarmplot(x=auto['fuel_type'], y=auto['horsepower'])
# Out:
# <Axes: xlabel='fuel_type', ylabel='horsepower'>

# %%
sns.boxplot(x=auto['number_of_doors'], y=auto['horsepower'])
# Out:
# <Axes: xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.boxplot(x=auto['number_of_doors'], y=auto['horsepower'], hue=auto['fuel_type'])
# Out:
# <Axes: xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.barplot(x=auto['number_of_doors'], y=auto['horsepower'], hue=auto['fuel_type'])
# Out:
# <Axes: xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.countplot(x=auto['body_style'], hue= auto['fuel_type'])
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
sns.pointplot(x=auto['body_style'], y=auto['horsepower'], hue=auto['number_of_doors'])
# Out:
# <Axes: xlabel='body_style', ylabel='horsepower'>

# %%
sns.catplot(x="fuel_type",
               y = "horsepower",
               hue="number_of_doors", 
               col="drive_wheels", 
               data=auto, 
               kind="box");

# %%
sns.catplot(x="fuel_type",
               y = "horsepower",
               hue="number_of_doors", 
               col="drive_wheels", 
               data=auto, 
               kind="violin");

# %%
sns.catplot(x="fuel_type",
               hue="number_of_doors", 
               col="drive_wheels", 
               data=auto, 
               kind="count");

# %%
# LINEAR REGRESSION MODEL INCOMING

# %%
sns.lmplot(y="horsepower", x="engine_size", data=auto);

# %%
sns.lmplot(y="horsepower", x="engine_size", hue="fuel_type", data=auto);
